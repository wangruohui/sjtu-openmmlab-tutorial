# %% [markdown]
# <img src="img/mmcls-logo.png">

# %% [markdown]
# # MMClassification 2.0 Tutorials
#
# <!--<badge>--><a href="https://colab.research.google.com/github/wangruohui/sjtu-openmmlab-tutorial/blob/main/v2.0/2-MMClassification_tutorials_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %% [markdown]
# **MMClassification Repo**：[https://github.com/open-mmlab/mmclassification](https://github.com/open-mmlab/mmclassification)
#
# **MMClassification 官方文档链接**：[https://mmclassification.readthedocs.io/en/1.x/index.html](https://mmclassification.readthedocs.io/en/1.x/index.html)
#
# **MMClassification 2.0 教学视频**：Coming Soon~
#
# **MMClassification 2.0 代码库介绍视频**：[https://www.bilibili.com/video/BV1x24y1R7mD](https://www.bilibili.com/video/BV1x24y1R7mD)
#
# **加入微信社群方式**：关注公众号，选择 “加入我们” -> “微信社区”，即可获取入群二维码。非常期待你的到来呀~
#
# **作者**：OpenMMLab
#
# ---

# %% [markdown]
# ## Outline
# 0. Installation
# 1. Inference
# 2. Training
# 3. Testing
# 4. Training on Custom Datasets
# 5. Useful Tools
#
# ---

# %% [markdown]
# ## 0. Installation
# **Step 1. 安装 MIM**
#
# **MIM**：MIM 为启动和安装 OpenMMLab 项目及其扩展以及管理 OpenMMLab 模型库提供了统一的接口。

# %%
# !pip install openmim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openmim
#   Downloading openmim-0.3.6-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 KB 2.4 MB/s eta 0:00:00
# Collecting rich
#   Downloading rich-13.3.2-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 KB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.9/dist-packages (from openmim) (22.0.4)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.9/dist-packages (from openmim) (8.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from openmim) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from openmim) (2.27.1)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (2022.12.7)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.4 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 8.1 MB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.15.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->model-index->openmim) (6.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.15.0)
# Installing collected packages: pygments, ordered-set, mdurl, colorama, markdown-it-py, rich, model-index, openmim
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# Successfully installed colorama-0.4.6 markdown-it-py-2.2.0 mdurl-0.1.2 model-index-0.1.11 openmim-0.3.6 ordered-set-4.1.0 pygments-2.14.0 rich-13.3.2

# %% [markdown]
# **Step 2. 安装依赖库 MMCV 和 MMEngine**

# %%
# !mim install mmengine "mmcv>=2.0.0rc1"
# Out:
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu116/torch1.13.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.7.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.8/365.8 KB 8.0 MB/s eta 0:00:00
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu116/torch1.13.0/mmcv-2.0.0rc4-cp39-cp39-manylinux1_x86_64.whl (47.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 MB 7.2 MB/s eta 0:00:00
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from mmengine) (2.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.9/dist-packages (from mmengine) (4.6.0.66)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmengine) (1.22.4)
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmengine) (13.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (5.12.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmengine) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.15.0)
# Installing collected packages: yapf, addict, mmengine, mmcv
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Successfully installed addict-2.4.0 mmcv-2.0.0rc4 mmengine-0.7.0 yapf-0.32.0

# %% [markdown]
# **Step 3. 安装 MMClassification**
#
# **-e**：以可编辑模式安装项目。加上该参数后，如果对本地代码进行了修改，则代码可以在不重新安装代码库的情况下生效。

# %%
# !git clone https://gitee.com/open-mmlab/mmclassification.git -b 1.x
# %cd mmclassification
# !pip install -e .
# Out:
# Cloning into 'mmclassification'...
# remote: Enumerating objects: 14220, done.
# remote: Counting objects: 100% (14220/14220), done.
# remote: Compressing objects: 100% (4878/4878), done.
# remote: Total 14220 (delta 10208), reused 12933 (delta 9110), pack-reused 0
# Receiving objects: 100% (14220/14220), 11.02 MiB | 598.00 KiB/s, done.
# Resolving deltas: 100% (10208/10208), done.
# /content/mmclassification
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmclassification
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmcls==1.0.0rc5) (3.7.1)
# Collecting modelindex
#   Downloading modelindex-0.0.2-py3-none-any.whl (2.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmcls==1.0.0rc5) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from mmcls==1.0.0rc5) (23.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmcls==1.0.0rc5) (13.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (4.39.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmcls==1.0.0rc5) (0.11.0)
# Requirement already satisfied: model-index in /usr/local/lib/python3.9/dist-packages (from modelindex->mmcls==1.0.0rc5) (0.1.11)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmcls==1.0.0rc5) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmcls==1.0.0rc5) (2.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmcls==1.0.0rc5) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmcls==1.0.0rc5) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmcls==1.0.0rc5) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from model-index->modelindex->mmcls==1.0.0rc5) (8.1.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from model-index->modelindex->mmcls==1.0.0rc5) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from model-index->modelindex->mmcls==1.0.0rc5) (3.4.1)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.9/dist-packages (from model-index->modelindex->mmcls==1.0.0rc5) (4.1.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->model-index->modelindex->mmcls==1.0.0rc5) (6.0.0)
# Installing collected packages: modelindex, mmcls
#   Running setup.py develop for mmcls
# Successfully installed mmcls-1.0.0rc5 modelindex-0.0.2

# %% [markdown]
# **Step 4. 查看安装是否正确**

# %%
import mmcls
print(mmcls.__version__)
# Out:
# 1.0.0rc5

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Inference
# 用 MMClassification [模型库](https://mmclassification.readthedocs.io/en/1.x/modelzoo_statistics.html#all-checkpoints)中预训练好的模型对图片进行预测。

# %% [markdown]
# **Step 1. 准备一张图片 `banana.png`**
#
# 如果 git clone 了源码，可以使用 `demo` 文件夹下的测试图像
#
# 也可以使用命令 `curl -o banana.png https://i.328888.xyz/2023/03/17/LruSP.png` 下载如下香蕉的图像
#
# <img src="img/banana.png">

# %% [markdown]
# **Step 2. 下载模型以及对应的配置文件**
#
# ```bash
# mim download ${PACKAGE} ${CONFIG_FILENAME} --dest ${DESTINATION_PATH}
# ```
#
# 训练工具 `mim download` 参数讲解：
#
# + PACKAGE：工具包名
# + CONFIG_FILENAME：配置文件的文件名。**注意：不要加 `.py`**
# + DESTINATION_PATH：下载文件保存路径
#
# 更多请参考：[链接](https://openmim.readthedocs.io/en/latest/api.html#module-mim.commands.download)

# %%
# !mim download mmcls --config mobilenet-v2_8xb32_in1k --dest tutorial/
# Out:
# processing mobilenet-v2_8xb32_in1k...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MiB 12.6 MB/s eta 0:00:00
# Successfully downloaded mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth to /content/mmclassification/tutorial
# Successfully dumped mobilenet-v2_8xb32_in1k.py to /content/mmclassification/tutorial

# %% [markdown]
# **Step 3. 用工具进行预测<font color = red>（没找到 mim 用于 inference）</font>**
#
# ```bash
# python demo/image_demo.py \
#     ${IMG_PATH} \
#     ${CONFIG_FILE} \
#     ${CHECKPOINT_PATH} \
#     [--device ${YOUR_DEVICE}]
# ```
#
# 推理工具 [demo/image_demo.py](https://github.com/open-mmlab/mmclassification/blob/1.x/demo/image_demo.py) 参数讲解:
# + IMG_PATH：测试图片所在路径
#
# + CONFIG_FILE：配置文件所在路径
#
# + CHECKPOINT_PATH：模型文件所在路径
#
# + device：设备，默认 'cuda:0'

# %%
# !python demo/image_demo.py demo/dog.jpg tutorial/mobilenet-v2_8xb32_in1k.py tutorial/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth
# 如果希望使用CPU，增加参数 --device cpu
# Out:
# 03/20 03:14:20 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Loads checkpoint by local backend from path: tutorial/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth
# /content/mmclassification/mmcls/apis/model.py:135: UserWarning: Class names are not saved in the checkpoint's meta data, use imagenet by default.
#   warnings.warn('Class names are not saved in the checkpoint\'s '
# 03/20 03:14:20 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# {
#   "pred_label": 179,
#   "pred_score": 0.27907595038414,
#   "pred_scores": [
#     2.108185253746342e-05,
#     1.150675572603177e-07,
#     4.625039196071157e-08,
#     1.0603583433521635e-07,
#     7.534158612543251e-07,
#     2.7889989269169746e-06,
#     1.2077547353328555e-06,
#     8.768444637041739e-09,
#     2.8897414239281716e-08,
#     4.02406152844037e-09,
#     3.681513760511734e-08,
#     2.129487057800361e-07,
#     5.4560970852435275e-08,
#     3.636621315195043e-08,
#     2.7556848181120586e-07,
#     8.167101994693837e-10,
#     1.2197249077416927e-07,
#     3.5064266512563336e-07,
#     2.607593252434981e-08,
#     5.4881496680536657e-08,
#     4.321694113684771e-09,
#     3.0815971996389635e-09,
#     2.0846266379770384e-10,
#     1.7824485212258878e-06,
#     9.602940664876769e-09,
#     6.651139017321839e-08,
#     8.540190776784584e-08,
#     9.42534406078721e-09,
#     1.0804092909211249e-07,
#     9.428050589121995e-07,
#     1.514901839527738e-07,
#     8.431003948317084e-07,
#     7.610892680531833e-06,
#     5.0937819651153404e-06,
#     1.4830461623205338e-05,
#     3.497406169117312e-07,
#     1.5301406165235676e-05,
# %% [markdown]
# ---

# %% [markdown]
# ## 2. Training
# 用 MMClassification 在 CIFAR10 数据集上训练分类模型 ResNet-18

# %% [markdown]
# **Step 1. 准备数据集**
#
# [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) 数据集包含 10 个类别共 60000 张图片，每个类别有 6000 张图片，其中 5000 张作为训练图片，1000 张作为测试图片。
#
# <img src="img/CIFAR.png">
#
# 我们推荐在 MMClassification 代码库的根目录下新建名为 `data` 的文件夹，并把数据集放在 `data` 文件夹里。
#
# MMClassification 支持**自动下载** CIFAR10 数据集，我们只需要在配置文件里的 `data_root` 字段里设置好数据存放的路径，同时用 `test_mode=False` 或者 `test_mode=True` 来区分训练集和测试集即可。
#
# ```bash
# train_dataloader = dict(
#     ...
#     # Training dataset configurations
#     dataset=dict(
#         type='CIFAR10',
#         data_root='data/cifar10',
#         test_mode=False,
#         pipeline=...,
#     )
# )
#
# val_dataloader = dict(
#     ...
#     # Validation dataset configurations
#     dataset=dict(
#         type='CIFAR10',
#         data_root='data/cifar10',
#         test_mode=True,
#         pipeline=...,
#     )
# )
#
# test_dataloader = val_dataloader
# ```
#
# 更多准备数据集的详情请参考：[链接](https://mmclassification.readthedocs.io/en/1.x/user_guides/dataset_prepare.html)

# %% [markdown]
# **Step 2. 下载 ResNet-18 模型的配置文件**

# %%
# !mim download mmcls --config resnet18_8xb16_cifar10 --dest tutorial/
# Out:
# processing resnet18_8xb16_cifar10...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MiB 12.3 MB/s eta 0:00:00
# Successfully downloaded resnet18_b16x8_cifar10_20210528-bd6371c8.pth to /content/mmclassification/tutorial
# Successfully dumped resnet18_8xb16_cifar10.py to /content/mmclassification/tutorial

# %% [markdown]
# **Step 3. 训练**
#
#
# 训练工具（需下载源码）tools/train.py
#
# 获取使用帮助：
# ```
# python tools/train.py -h
#
# usage: train.py [-h] [--work-dir WORK_DIR] [--resume [RESUME]] [--amp]
#                 [--no-validate] [--auto-scale-lr] [--no-pin-memory]
#                 [--no-persistent-workers]
#                 [--cfg-options CFG_OPTIONS [CFG_OPTIONS ...]]
#                 [--launcher {none,pytorch,slurm,mpi}]
#                 [--local_rank LOCAL_RANK]
#                 config
# ```

# %%
# !python tools/train.py tutorial/resnet18_8xb16_cifar10.py --auto-scale-lr
# Out:
# 03/20 03:14:48 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1429212364
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.7.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 03:14:48 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet_CIFAR',
#         depth=18,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=10,
#         in_channels=512,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0)))
# dataset_type = 'CIFAR10'
# data_preprocessor = dict(
#     num_classes=10,
#     mean=[125.307, 122.961, 113.8575],
#     std=[51.5865, 50.847, 51.255],
#     to_rgb=False)
# train_pipeline = [
#     dict(type='RandomCrop', crop_size=32, padding=4),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [dict(type='PackClsInputs')]
# train_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10',
#         test_mode=False,
#         pipeline=[
#             dict(type='RandomCrop', crop_size=32, padding=4),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10/',
#         test_mode=True,
#         pipeline=[dict(type='PackClsInputs')]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, ))
# test_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10/',
#         test_mode=True,
#         pipeline=[dict(type='PackClsInputs')]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, ))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[100, 150], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=200, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=128, enable=True)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = None
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/resnet18_8xb16_cifar10'
#
# 03/20 03:14:48 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:14:48 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:14:48 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:14:53 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 03:14:53 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:14:53 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 03:14:53 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:14:53 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar10/cifar-10-python.tar.gz
# 170.5/170.5 MB ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0:00:00
# Extracting data/cifar10/cifar-10-python.tar.gz to data/cifar10
# 03/20 03:15:00 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:00 - mmengine - WARNING - The "optimizer wrapper constructor" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:00 - mmengine - WARNING - The "optimizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:00 - mmengine - WARNING - The "optimizer_wrapper" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:00 - mmengine - INFO - LR is set based on batch size of 128 and the current batch size is 16. Scaling the original LR by 0.125.
# 03/20 03:15:00 - mmengine - WARNING - The "parameter scheduler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:02 - mmengine - WARNING - The "metric" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:02 - mmengine - WARNING - The "weight initializer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:02 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/20 03:15:02 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 03/20 03:15:02 - mmengine - INFO - Checkpoints will be saved to /content/mmclassification/work_dirs/resnet18_8xb16_cifar10.
# 03/20 03:15:13 - mmengine - INFO - Epoch(train)   [1][ 100/3125]  lr: 1.2500e-02  eta: 20:10:55  time: 0.0297  data_time: 0.0039  memory: 242  loss: 2.1673
# 03/20 03:15:16 - mmengine - INFO - Epoch(train)   [1][ 200/3125]  lr: 1.2500e-02  eta: 12:23:20  time: 0.0254  data_time: 0.0005  memory: 242  loss: 2.2265
# 03/20 03:15:19 - mmengine - INFO - Epoch(train)   [1][ 300/3125]  lr: 1.2500e-02  eta: 9:44:39  time: 0.0254  data_time: 0.0007  memory: 242  loss: 2.2338
# 03/20 03:15:21 - mmengine - INFO - Epoch(train)   [1][ 400/3125]  lr: 1.2500e-02  eta: 8:24:53  time: 0.0269  data_time: 0.0013  memory: 242  loss: 2.0805
# 03/20 03:15:24 - mmengine - INFO - Epoch(train)   [1][ 500/3125]  lr: 1.2500e-02  eta: 7:37:30  time: 0.0253  data_time: 0.0005  memory: 242  loss: 1.9652
# Traceback (most recent call last):
#   File "/content/mmclassification/tools/train.py", line 162, in <module>
#     main()
#   File "/content/mmclassification/tools/train.py", line 158, in main
#     runner.train()
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/runner.py", line 1701, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 112, in run_epoch
#     self.run_iter(idx, data_batch)
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/runner/loops.py", line 128, in run_iter
#     outputs = self.runner.model.train_step(
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/model/base_model/base_model.py", line 114, in train_step
#     losses = self._run_forward(data, mode='loss')  # type: ignore
#   File "/usr/local/lib/python3.9/dist-packages/mmengine/model/base_model/base_model.py", line 326, in _run_forward
#     results = self(**data, mode=mode)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/mmclassification/mmcls/models/classifiers/image.py", line 114, in forward
#     return self.loss(inputs, data_samples)
#   File "/content/mmclassification/mmcls/models/classifiers/image.py", line 223, in loss
#     feats = self.extract_feat(inputs)
#   File "/content/mmclassification/mmcls/models/classifiers/image.py", line 196, in extract_feat
#     x = self.backbone(inputs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/mmclassification/mmcls/models/backbones/resnet_cifar.py", line 78, in forward
#     x = res_layer(x)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/container.py", line 204, in forward
#     input = module(input)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/mmclassification/mmcls/models/backbones/resnet.py", line 130, in forward
#     out = _inner_forward(x)
#   File "/content/mmclassification/mmcls/models/backbones/resnet.py", line 112, in _inner_forward
#     out = self.norm1(out)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/batchnorm.py", line 151, in forward
#     self.num_batches_tracked.add_(1)  # type: ignore[has-type]
# KeyboardInterrupt
# ^C

# %% [markdown]
# **Step 4. 理解打印出来的 log 日志文件**
# + 系统环境
# + 配置文件
# + 训练过程中学习率的变化、loss 变化、消耗时间、消耗内存
# + 验证集上的准确率

# %% [markdown]
# **Step 5. 训练结果保存位置**
#
# 训练过程中，日志和模型参数会保存在 *working directory* 下面，默认是当前目录下的 `work_dir` 文件，例：
#
# ```plain
# $ tree work_dirs/
# work_dirs/
# └── resnet18_8xb16_cifar10
#     ├── 20230317_183400
#     │   ├── 20230317_183400.log
#     │   └── vis_data
#     │       ├── 20230317_183400.json
#     │       ├── config.py
#     │       └── scalars.json
#     ├── epoch_1.pth
#     ├── last_checkpoint
#     └── resnet18_8xb16_cifar10.py
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Testing
# 用 MMClassification 在 CIFAR10 数据集上测试分类模型 ResNet-18

# %% [markdown]
# **Step 1. 准备数据集**
#
# 我们依旧使用 [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) 数据集来演示

# %% [markdown]
# **Step 2. 下载 ResNet-18 模型以及对应的配置文件**
#
# 我们直接使用上一节下载好的 ResNet-18 模型即可。

# %% [markdown]
# **Step 3. 用工具开始测试**
#
# ```bash
# mim test ${PACKAGE} ${CONFIG_FILE} --checkpoint ${CHECKPOINT_FILE} --out ${OUT_FILE} --dump ${DUMP_FILE} --other_args ${OTHER_ARGS}
# ```
#
# 训练工具 `mim test` 参数讲解：
#
# + PACKAGE：工具包名
# + CONFIG_FILE：配置文件所在路径
# + CHECKPOINT_FILE：模型文件所在路径
# + OTHER_ARGS: 其他和各自工具包（代码库）相关的参数。比如 MMClassification 中的
#     + OUT_FILE：保存模型在测试集上的整体评估结果文件所在路径。默认自动保存在 `work_dir` 文件夹下
#     + DUMP_FILE：保存模型对每个样本的预测结果文件所在路径。默认不设置该参数，也就是不会保存该文件。如果要保存该文件，文件命名必须以 .pkl 为后缀
#
#
# 更多请参考：[链接](https://openmim.readthedocs.io/en/latest/api.html#module-mim.commands.test)

# %%
# !python tools/test.py tutorial/resnet18_8xb16_cifar10.py tutorial/resnet18_b16x8_cifar10_20210528-bd6371c8.pth --dump tutorial/result_cifar.pkl
# Out:
# 03/20 03:15:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1088158299
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.7.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 03:15:41 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(
#         type='ResNet_CIFAR',
#         depth=18,
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch'),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=10,
#         in_channels=512,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0)))
# dataset_type = 'CIFAR10'
# data_preprocessor = dict(
#     num_classes=10,
#     mean=[125.307, 122.961, 113.8575],
#     std=[51.5865, 50.847, 51.255],
#     to_rgb=False)
# train_pipeline = [
#     dict(type='RandomCrop', crop_size=32, padding=4),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [dict(type='PackClsInputs')]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10',
#         test_mode=False,
#         pipeline=[
#             dict(type='RandomCrop', crop_size=32, padding=4),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10/',
#         test_mode=True,
#         pipeline=[dict(type='PackClsInputs')]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, ))
# test_dataloader = dict(
#     pin_memory=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=16,
#     num_workers=2,
#     dataset=dict(
#         type='CIFAR10',
#         data_prefix='data/cifar10/',
#         test_mode=True,
#         pipeline=[dict(type='PackClsInputs')]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = [
#     dict(type='Accuracy', topk=(1, )),
#     dict(type='DumpResults', out_file_path='tutorial/result_cifar.pkl')
# ]
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0001))
# param_scheduler = dict(
#     type='MultiStepLR', by_epoch=True, milestones=[100, 150], gamma=0.1)
# train_cfg = dict(by_epoch=True, max_epochs=200, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=128)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'tutorial/resnet18_b16x8_cifar10_20210528-bd6371c8.pth'
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/resnet18_8xb16_cifar10'
#
# 03/20 03:15:41 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:41 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:41 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:43 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 03:15:43 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:43 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 03:15:43 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:43 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:44 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:44 - mmengine - WARNING - The "metric" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 03:15:44 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: tutorial/resnet18_b16x8_cifar10_20210528-bd6371c8.pth
# 03/20 03:15:45 - mmengine - INFO - Load checkpoint from tutorial/resnet18_b16x8_cifar10_20210528-bd6371c8.pth
# 03/20 03:15:47 - mmengine - INFO - Epoch(test) [100/625]    eta: 0:00:13  time: 0.0096  data_time: 0.0003  memory: 83
# 03/20 03:15:48 - mmengine - INFO - Epoch(test) [200/625]    eta: 0:00:07  time: 0.0093  data_time: 0.0003  memory: 83
# 03/20 03:15:49 - mmengine - INFO - Epoch(test) [300/625]    eta: 0:00:04  time: 0.0099  data_time: 0.0004  memory: 83
# 03/20 03:15:50 - mmengine - INFO - Epoch(test) [400/625]    eta: 0:00:03  time: 0.0098  data_time: 0.0003  memory: 83
# 03/20 03:15:51 - mmengine - INFO - Epoch(test) [500/625]    eta: 0:00:01  time: 0.0098  data_time: 0.0003  memory: 83
# 03/20 03:15:52 - mmengine - INFO - Epoch(test) [600/625]    eta: 0:00:00  time: 0.0125  data_time: 0.0030  memory: 83
# 03/20 03:15:56 - mmengine - INFO - Results has been saved to tutorial/result_cifar.pkl.
# 03/20 03:15:56 - mmengine - INFO - Epoch(test) [625/625]  accuracy/top1: 94.8200data_time: 0.0021  time: 0.0114

# %% [markdown]
# **Step 4. 加载保存下来的评估结果文件**

# %%
import mmengine
res = mmengine.load('tutorial/result_cifar.pkl')
# res 是一个列表，长度=10000=cifar的测试集的大小
print(res[0])   # res[0] 是一个字典，包含了预测的类别和概率

# %% [markdown]
# **自定义多 metrics 测试（暂时还有bug，修复还未合入1.x）**
#
# 除了 `Top-1 Accuracy`，MMClassification 还支持许多其他评估指标（详情请参考：[链接](https://mmclassification.readthedocs.io/en/1.x/advanced_guides/evaluation.html)），我们只需要修改配置文件中的 `val_evaluator` 和 `test_evaluator` 里的内容即可。

# %%
# !cp tutorial/resnet18_8xb16_cifar10.py tutorial/resnet18_8xb16_cifar10_4metrics.py

# %% [markdown]
# 比如，我们要测试模型的 `Top-1 Accuracy`、 `Top-5 Accuracy`、 `precision` 和 `recall`，只需要将配置文件中 `val_evaluator` 和 `test_evaluator` 的内容修改成这样：
#
# ``` python
# val_evaluator = [
#   dict(type='Accuracy', topk=(1, 5)),
#   dict(type='SingleLabelMetric', items=['precision', 'recall']),
# ]
# test_evaluator = val_evaluator
# ```

# %%
# !python tools/test.py configs/resnet/resnet18_8xb16_cifar10_4matrics.py --checkpoint tutorial/resnet18_b16x8_cifar10_20210528-bd6371c8.pth --dump tutorial/result_cifar_4metrics.pkl

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Training on Custom Datasets
# 用 MMClassification 在自定义数据集上训练分类模型。
#
# MMClassification 中支持自定义数据集的方法有 3 种：
# 1. 按照 `CustomDataset` 的数据格式整理数据集（[详情](https://mmclassification.readthedocs.io/en/1.x/user_guides/dataset_prepare.html#customdataset)）
# 2. 按照 `OpenMMLab 2.0 标注数据集` 的数据格式整理数据集（[详情](https://mmclassification.readthedocs.io/en/1.x/user_guides/dataset_prepare.html#openmmlab-2-0-standard-dataset)）
# 3. 自己实现一种数据集类型
#
# 我们在这里演示第 1 种：将数据整理成 `CustomDataset` 的格式。
#
# 在这种格式的数据集里，图片有多少个类别，就会有多少个子文件夹，子文件夹以`类名`命名，数据按类别存放在对应的子文件内。
#
# 比如：
# <img src="img/CustomDataset_category.png">

# %% [markdown]
# **Step 1. 准备数据集**
#
# 我们这里使用的是同济子豪兄收集的水果数据集，该数据集有 30 个类别的图片。训练集里每个类别有 100+ 张图片，测试集里每个类别有 30+ 张图片。该数据集已经按 `CustomDataset` 的格式整理好了，直接使用即可。
#
# 如果希望使用自己整理的数据集，最简单的方式就是把数据按照类别放在不同的文件夹中，文件夹名为类别名。
#
# 我们在 MMClassification 代码库的根目录下新建名为 `data` 的文件夹，并把数据集下载放在 `data` 文件夹里。

# %%
# !wget -P data https://link.jscdn.cn/1drv/aHR0cHM6Ly8xZHJ2Lm1zL3UvcyFBdXJWRlJFSkF4ekxnUWFGdjV0UmE4UGdMNG9vP2U9UlgxRm5V.zip

# %% [markdown]
# 解压数据集

# %%
# !unzip -q data/fruit30_split_en.zip -d data

# %% [markdown]
# 查看数据集的目录（跳过）

# %%
# !apt-get install tree
# !tree -d data/fruit30_split_en
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 23 not upgraded.
# Need to get 43.0 kB of archives.
# After this operation, 115 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tree amd64 1.8.0-1 [43.0 kB]
# Fetched 43.0 kB in 0s (105 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 128276 files and directories currently installed.)
# Preparing to unpack .../tree_1.8.0-1_amd64.deb ...
# Unpacking tree (1.8.0-1) ...
# Setting up tree (1.8.0-1) ...
# Processing triggers for man-db (2.9.1-1) ...
# data/fruit30_split_en
# ├── train
# │   ├── banana
# │   ├── bayberry
# │   ├── bitter-melon
# │   ├── cantaloupe
# │   ├── carrot
# │   ├── cherry
# │   ├── cherry-tomato
# │   ├── coconut
# │   ├── cucumber
# │   ├── durian
# │   ├── green-apple
# │   ├── kiwi
# │   ├── lemon
# │   ├── litchi
# │   ├── longan
# │   ├── mango
# │   ├── mangosteen
# │   ├── navel-orange
# │   ├── pear
# │   ├── pineapple
# │   ├── pitaya
# │   ├── pomegranate
# │   ├── pomelo
# │   ├── red-apple
# │   ├── red-grapes
# │   ├── strawberry
# │   ├── tangerine
# │   ├── tomato
# │   ├── watermelon
# │   └── white-grapes
# └── val
#     ├── banana
#     ├── bayberry
#     ├── bitter-melon
#     ├── cantaloupe
#     ├── carrot
#     ├── cherry
#     ├── cherry-tomato
#     ├── coconut
#     ├── cucumber
#     ├── durian
#     ├── green-apple
#     ├── kiwi
#     ├── lemon
#     ├── litchi
#     ├── longan
#     ├── mango
#     ├── mangosteen
#     ├── navel-orange
#     ├── pear
#     ├── pineapple
#     ├── pitaya
#     ├── pomegranate
#     ├── pomelo
#     ├── red-apple
#     ├── red-grapes
#     ├── strawberry
#     ├── tangerine
#     ├── tomato
#     ├── watermelon
#     └── white-grapes
#
# 62 directories

# %% [markdown]
# **Step 2. 下载模型以及对应的配置文件**
#
# 我们直接使用第 1 节下载好的 MobileNet v2 模型即可，复制一个出来供修改

# %%
# !cp tutorial/mobilenet-v2_8xb32_in1k.py tutorial/fruit.py

# %% [markdown]
# **Step 3. 修改配置文件**
# + 复制配置文件，并命名为 `fruit.py`
# + 修改模型
#     + 修改模型 `model` 里的类别数目 `num_classes`，设置为 30
#     + 修改模型权值的加载路径 `load_from` ，设置为下载下来的 MobileNet v2 模型所在的路径
# + 修改数据
#     + 将数据集类型 `dataset_type` 的值修改为 `CustomDataset`
#     + 将训练加载器、验证加载器和测试加载器的数据集根目录 `data_root` 设置为 `data/fruit30_split_en`
#     + 将训练加载器、验证加载器和测试加载器的数据集标注文件 `ann_file` 项删除，表示用文件夹名作为类名
# + 修改训练配置
#     + 将 `train_cfg` 里的 `max_epochs` 改为 5
# + 修改优化器
#     + 将 `optim_wrapper ` 里的 `lr` 改为 0.005 （finetune需要使用小学习率）
#     + 将 `lr_scheluler` 里的 `gamma` 改为 0.5 （训练过程中需要降低学习率以收敛到更高精度）
# + 修改杂项
#     + 打印日志的间隔 `LoggerHook` 改为 10
#     + 保存模型文件的间隔 `CheckpointHook`
#
# LR Scheduler 的更多调整可参考 https://mmengine.readthedocs.io/en/latest/tutorials/param_scheduler.html

# %% [markdown]
# **Step 4. 用工具开始训练**

# %%
# !python tools/train.py tutorial/fruit.py --auto-scale-lr
# Out:
# 03/20 05:17:05 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 893588428
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.7.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 05:17:05 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(type='MobileNetV2', widen_factor=1.0),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=1280,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)))
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     num_classes=30,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackClsInputs')
# ]
# train_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     pin_memory=True,
#     persistent_workers=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = dict(type='Accuracy', topk=(1, 5))
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.005, momentum=0.9, weight_decay=4e-05))
# param_scheduler = dict(type='StepLR', by_epoch=True, step_size=1, gamma=0.98)
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256, enable=True)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=60),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'tutorial/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth'
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/mobilenet-v2_1xb32_fruit30'
#
# 03/20 05:17:05 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:05 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:06 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 05:17:08 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 05:17:08 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 03/20 05:17:08 - mmengine - WARNING - The "optimizer wrapper constructor" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "optimizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "optimizer_wrapper" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - INFO - LR is set based on batch size of 256 and the current batch size is 32. Scaling the original LR by 0.125.
# 03/20 05:17:08 - mmengine - WARNING - The "parameter scheduler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "metric" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:17:08 - mmengine - WARNING - The "weight initializer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Loads checkpoint by local backend from path: tutorial/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for head.fc.weight: copying a param with shape torch.Size([1000, 1280]) from checkpoint, the shape in current model is torch.Size([30, 1280]).
# size mismatch for head.fc.bias: copying a param with shape torch.Size([1000]) from checkpoint, the shape in current model is torch.Size([30]).
# 03/20 05:17:09 - mmengine - INFO - Load checkpoint from tutorial/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth
# 03/20 05:17:09 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/20 05:17:09 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 03/20 05:17:09 - mmengine - INFO - Checkpoints will be saved to /content/mmclassification/work_dirs/mobilenet-v2_1xb32_fruit30.
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# 03/20 05:23:02 - mmengine - INFO - Saving checkpoint at 9 epochs
# 03/20 05:23:08 - mmengine - INFO - Epoch(val) [9][34/34]  accuracy/top1: 91.2802  accuracy/top5: 98.8868data_time: 0.0740  time: 0.1088
# 03/20 05:23:23 - mmengine - INFO - Epoch(train) [10][ 60/137]  lr: 5.2109e-04  eta: 0:00:18  time: 0.2031  data_time: 0.0781  memory: 2455  loss: 0.2974
# 03/20 05:23:37 - mmengine - INFO - Epoch(train) [10][120/137]  lr: 5.2109e-04  eta: 0:00:04  time: 0.2239  data_time: 0.0987  memory: 2455  loss: 0.3426
# 03/20 05:23:40 - mmengine - INFO - Exp name: mobilenet-v2_1xb32_fruit30_20230320_051704
# 03/20 05:23:40 - mmengine - INFO - Saving checkpoint at 10 epochs
# 03/20 05:23:49 - mmengine - INFO - Epoch(val) [10][34/34]  accuracy/top1: 91.9295  accuracy/top5: 98.9796data_time: 0.0555  time: 0.0875

# %% [markdown]
# **Step 5. 理解打印出来的 log 日志文件**
# + 系统环境
# + 配置文件
# + 检查模型初始化记录：`Loads checkpoint by local backend from path: .../mmclassification/mobilenet_v2_batch256_imagenet_20200708-3b2dc3af.pth`
# + 训练过程中学习率的变化、loss 变化、消耗时间、消耗内存
# + 验证集上的准确率

# %% [markdown]
# **Step 6. 测试训练好的模型**

# %%
# !python demo/image_demo.py banana.png tutorial/fruit.py work_dirs/fruit/epoch_5.pth

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Useful Tools

# %% [markdown]
# ### 5.1 计算模型的参数量和计算量
#
# **Step 1. 运行工具 `mim run`**
#
# ```bash
# mim run ${PACKAGE} ${COMMAND} --yes ${YES} --other_args ${OTHER_ARGS}
# ```
# 参数讲解：
# + PACKAGE：工具包名
# + COMMAND：运行命令的名字
# + YES：不要求确认。bool类型的变量，默认为 True
# + OTHER_ARGS: 其他传入各工具包运行命令的参数
#
# 更多请参考：[链接](https://openmim.readthedocs.io/en/latest/api.html#module-mim.commands.run)

# %% [markdown]
# 如果想查看某个工具包支持哪些命令以及使用方法，可使用命令：
#
# ```bash
# mim run ${PACKAGE} -h
# ```
#
# 比如，查看 MMClassification 目前支持的命令：

# %%
# !mim run mmcls -h
# Out:
# Usage: mim run [OPTIONS] PACKAGE COMMAND
#                [OTHER_ARGS]...
#
#   Run arbitrary command of a codebase.
#
#   Note if the command you call takes config files
#   or checkpoint paths as arguments, you must use
#   paths that do exists. We do not accept URLs or
#   config names (like resnet101_b16x8_cifar10.py)
#   if that doesn't exist under your current
#   directory.
#
#   Example:
#
#   # Get the Flops of a model
#   > mim run mmcls get_flops resnet101_b16x8_cifar10.py
#   # Publish a model
#   > mim run mmcls publish_model input.pth output.pth
#   # Train models on a slurm HPC with one GPU
#   > srun -p partition --gres=gpu:1 mim run mmcls train         resnet101_b16x8_cifar10.py --work-dir tmp
#   # Test models on a slurm HPC with one GPU, report accuracy
#   > srun -p partition --gres=gpu:1 mim run mmcls test         resnet101_b16x8_cifar10.py tmp/epoch_3.pth --metrics accuracy
#   # Print help messages of sub-command run
#   > mim run -h
#   # Print help messages of sub-command run, list all available scripts in
#   # codebase mmcls
#   > mim run mmcls -h
#   # Print help messages of sub-command run, print the help message of
#   # training script in mmcls
#   > mim run mmcls train -h
#
# Options:
#   -y, --yes   Don't ask for confirmation.
#   -h, --help  Show this message and exit.
#
# ================================================================================
# Available scripts in mmcls are:
# kfold-cross-valid: kfold-cross-valid.py
# test: test.py
# train: train.py
# torchserve:mmcls_handler: torchserve/mmcls_handler.py
# torchserve:test_torchserver: torchserve/test_torchserver.py
# torchserve:mmcls2torchserve: torchserve/mmcls2torchserve.py
# analysis_tools:analyze_results: analysis_tools/analyze_results.py
# analysis_tools:get_flops: analysis_tools/get_flops.py
# analysis_tools:eval_metric: analysis_tools/eval_metric.py
# analysis_tools:analyze_logs: analysis_tools/analyze_logs.py
# model_converters:efficientnet_to_mmcls: model_converters/efficientnet_to_mmcls.py
# model_converters:convnext_to_mmcls: model_converters/convnext_to_mmcls.py
# model_converters:publish_model: model_converters/publish_model.py
# model_converters:reparameterize_model: model_converters/reparameterize_model.py
# model_converters:revvit_to_mmcls: model_converters/revvit_to_mmcls.py
# model_converters:mobilenetv2_to_mmcls: model_converters/mobilenetv2_to_mmcls.py
# model_converters:repvgg_to_mmcls: model_converters/repvgg_to_mmcls.py
# model_converters:mlpmixer_to_mmcls: model_converters/mlpmixer_to_mmcls.py
# model_converters:efficientnetv2_to_mmcls: model_converters/efficientnetv2_to_mmcls.py
# model_converters:edgenext_to_mmcls: model_converters/edgenext_to_mmcls.py
# model_converters:torchvision_to_mmcls: model_converters/torchvision_to_mmcls.py
# model_converters:van2mmcls: model_converters/van2mmcls.py
# model_converters:twins2mmcls: model_converters/twins2mmcls.py
# model_converters:deit3_to_mmcls: model_converters/deit3_to_mmcls.py
# model_converters:hornet2mmcls: model_converters/hornet2mmcls.py
# model_converters:davit_to_mmcls: model_converters/davit_to_mmcls.py
# model_converters:vgg_to_mmcls: model_converters/vgg_to_mmcls.py
# model_converters:eva_to_mmcls: model_converters/eva_to_mmcls.py
# model_converters:shufflenetv2_to_mmcls: model_converters/shufflenetv2_to_mmcls.py
# model_converters:mixmimx_to_mmcls: model_converters/mixmimx_to_mmcls.py
# model_converters:clip_to_mmcls: model_converters/clip_to_mmcls.py
# model_converters:tinyvit_to_mmcls: model_converters/tinyvit_to_mmcls.py
# model_converters:replknet_to_mmcls: model_converters/replknet_to_mmcls.py
# visualizations:browse_dataset: visualizations/browse_dataset.py
# visualizations:vis_cam: visualizations/vis_cam.py
# visualizations:vis_scheduler: visualizations/vis_scheduler.py
# misc:verify_dataset: misc/verify_dataset.py
# misc:print_config: misc/print_config.py

# %% [markdown]
# **Step 2. 安装 `fvcore`**

# %%
# !pip install fvcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fvcore) (1.22.4)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from fvcore) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from fvcore) (4.65.0)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.9/dist-packages (from fvcore) (2.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from fvcore) (8.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from fvcore) (0.8.10)
# Collecting iopath>=0.1.7
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.9/dist-packages (from iopath>=0.1.7->fvcore) (4.5.0)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61429 sha256=3742608e104422bab51c02ff1b432aa2685e9f2b55b370b3182ee2e7b4b7552c
#   Stored in directory: /root/.cache/pip/wheels/83/42/02/66178d16e5c44dc26d309931834956baeda371956e86fbd876
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=7794bc84f5b14b7c4b3c2183af31ebe45103cea427be54c019b844618e78a487
#   Stored in directory: /root/.cache/pip/wheels/c1/13/6d/441d8f2af76ee6d2a3e67eebb1d0c556fefcee0a8b32266a8e
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.7.0 yacs-0.1.8

# %% [markdown]
# **Step 3. 计算 Resnet-18 模型的参数量和计算量**
#
# ```bash
# mim run mmcls get_flops ${CONFIG_FILE} --shape ${INPUT_SHAPE}
# ```
# 参数讲解：
# + CONFIG_FILE：配置文件所在路径
# + INPUT_SHAPE：设置输入形状。支持设置一个值或者两个值，比如 `--shape 256` 或者 `--shape 224 256`，如果不设置该参数，则默认输入形状设置为 `--shape 224 224`
#
# 详情请参考：[链接](https://mmclassification.readthedocs.io/en/latest/tools/analysis.html#get-the-flops-and-params-experimental)

# %%
# !mim run mmcls get_flops tutorial/resnet18_8xb16_cifar10.py
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/analysis_tools/get_flops.py for command get_flops.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/analysis_tools/get_flops.py tutorial/resnet18_8xb16_cifar10.py.
# 03/20 05:15:43 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Unsupported operator aten::add_ encountered 8 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# data_preprocessor, head, head.fc, head.loss_module
# Unsupported operator aten::batch_norm encountered 20 time(s)
# Unsupported operator aten::add_ encountered 8 time(s)
# Unsupported operator aten::adaptive_avg_pool2d encountered 1 time(s)
# The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# data_preprocessor, head, head.fc, head.loss_module
#
# N/A indicates a possibly missing statistic due to how the module was called. Missing values are still included in the parent's total.
# ImageClassifier(
#   #params: 11.17M, #flops: 27.28G, #acts: 30.11M
#   (data_preprocessor): ClsDataPreprocessor(#params: 0, #flops: N/A, #acts: N/A)
#   (backbone): ResNet_CIFAR(
#     #params: 11.17M, #flops: 27.28G, #acts: 30.11M
#     (conv1): Conv2d(
#       3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#       #params: 1.73K, #flops: 86.7M, #acts: 3.21M
#     )
#     (bn1): BatchNorm2d(
#       64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       #params: 0.13K, #flops: 6.42M, #acts: 0
#     )
#     (relu): ReLU(inplace=True)
#     (layer1): ResLayer(
#       #params: 0.15M, #flops: 7.42G, #acts: 12.85M
#       (0): BasicBlock(
#         #params: 73.98K, #flops: 3.71G, #acts: 6.42M
#         (conv1): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 36.86K, #flops: 1.85G, #acts: 3.21M
#         )
#         (bn1): BatchNorm2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.13K, #flops: 6.42M, #acts: 0
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 36.86K, #flops: 1.85G, #acts: 3.21M
#         )
#         (bn2): BatchNorm2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.13K, #flops: 6.42M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#       (1): BasicBlock(
#         #params: 73.98K, #flops: 3.71G, #acts: 6.42M
#         (conv1): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 36.86K, #flops: 1.85G, #acts: 3.21M
#         )
#         (bn1): BatchNorm2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.13K, #flops: 6.42M, #acts: 0
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 36.86K, #flops: 1.85G, #acts: 3.21M
#         )
#         (bn2): BatchNorm2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.13K, #flops: 6.42M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#     )
#     (layer2): ResLayer(
#       #params: 0.53M, #flops: 6.59G, #acts: 8.03M
#       (0): BasicBlock(
#         #params: 0.23M, #flops: 2.89G, #acts: 4.82M
#         (conv1): Conv2d(
#           64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           #params: 73.73K, #flops: 0.92G, #acts: 1.61M
#         )
#         (bn1): BatchNorm2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.26K, #flops: 3.21M, #acts: 0
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.15M, #flops: 1.85G, #acts: 1.61M
#         )
#         (bn2): BatchNorm2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.26K, #flops: 3.21M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           #params: 8.45K, #flops: 0.11G, #acts: 1.61M
#           (0): Conv2d(
#             64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             #params: 8.19K, #flops: 0.1G, #acts: 1.61M
#           )
#           (1): BatchNorm2d(
#             128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             #params: 0.26K, #flops: 3.21M, #acts: 0
#           )
#         )
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#       (1): BasicBlock(
#         #params: 0.3M, #flops: 3.71G, #acts: 3.21M
#         (conv1): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.15M, #flops: 1.85G, #acts: 1.61M
#         )
#         (bn1): BatchNorm2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.26K, #flops: 3.21M, #acts: 0
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.15M, #flops: 1.85G, #acts: 1.61M
#         )
#         (bn2): BatchNorm2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.26K, #flops: 3.21M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#     )
#     (layer3): ResLayer(
#       #params: 2.1M, #flops: 6.58G, #acts: 4.01M
#       (0): BasicBlock(
#         #params: 0.92M, #flops: 2.88G, #acts: 2.41M
#         (conv1): Conv2d(
#           128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           #params: 0.29M, #flops: 0.92G, #acts: 0.8M
#         )
#         (bn1): BatchNorm2d(
#           256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.51K, #flops: 1.61M, #acts: 0
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.59M, #flops: 1.85G, #acts: 0.8M
#         )
#         (bn2): BatchNorm2d(
#           256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.51K, #flops: 1.61M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           #params: 33.28K, #flops: 0.1G, #acts: 0.8M
#           (0): Conv2d(
#             128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             #params: 32.77K, #flops: 0.1G, #acts: 0.8M
#           )
#           (1): BatchNorm2d(
#             256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             #params: 0.51K, #flops: 1.61M, #acts: 0
#           )
#         )
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#       (1): BasicBlock(
#         #params: 1.18M, #flops: 3.7G, #acts: 1.61M
#         (conv1): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.59M, #flops: 1.85G, #acts: 0.8M
#         )
#         (bn1): BatchNorm2d(
#           256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.51K, #flops: 1.61M, #acts: 0
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 0.59M, #flops: 1.85G, #acts: 0.8M
#         )
#         (bn2): BatchNorm2d(
#           256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 0.51K, #flops: 1.61M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#     )
#     (layer4): ResLayer(
#       #params: 8.39M, #flops: 6.58G, #acts: 2.01M
#       (0): BasicBlock(
#         #params: 3.67M, #flops: 2.88G, #acts: 1.2M
#         (conv1): Conv2d(
#           256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False
#           #params: 1.18M, #flops: 0.92G, #acts: 0.4M
#         )
#         (bn1): BatchNorm2d(
#           512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 1.02K, #flops: 0.8M, #acts: 0
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 2.36M, #flops: 1.85G, #acts: 0.4M
#         )
#         (bn2): BatchNorm2d(
#           512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 1.02K, #flops: 0.8M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           #params: 0.13M, #flops: 0.1G, #acts: 0.4M
#           (0): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             #params: 0.13M, #flops: 0.1G, #acts: 0.4M
#           )
#           (1): BatchNorm2d(
#             512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             #params: 1.02K, #flops: 0.8M, #acts: 0
#           )
#         )
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#       (1): BasicBlock(
#         #params: 4.72M, #flops: 3.7G, #acts: 0.8M
#         (conv1): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 2.36M, #flops: 1.85G, #acts: 0.4M
#         )
#         (bn1): BatchNorm2d(
#           512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 1.02K, #flops: 0.8M, #acts: 0
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           #params: 2.36M, #flops: 1.85G, #acts: 0.4M
#         )
#         (bn2): BatchNorm2d(
#           512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           #params: 1.02K, #flops: 0.8M, #acts: 0
#         )
#         (relu): ReLU(inplace=True)
#         (drop_path): Identity(#params: 0, #flops: N/A, #acts: N/A)
#       )
#     )
#   )
#   (neck): GlobalAveragePooling(
#     #params: 0, #flops: 0.4M, #acts: 0
#     (gap): AdaptiveAvgPool2d(
#       output_size=(1, 1)
#       #params: 0, #flops: 0.4M, #acts: 0
#     )
#   )
#   (head): LinearClsHead(
#     #params: 5.13K, #flops: N/A, #acts: N/A
#     (loss_module): CrossEntropyLoss(#params: 0, #flops: N/A, #acts: N/A)
#     (fc): Linear(
#       in_features=512, out_features=10, bias=True
#       #params: 5.13K, #flops: N/A, #acts: N/A
#     )
#   )
# )
#
# | module                   | #parameters or shape   | #flops    | #activations   |
# |:-------------------------|:-----------------------|:----------|:---------------|
# | model                    | 11.174M                | 27.276G   | 30.106M        |
# |  backbone                |  11.169M               |  27.276G  |  30.106M       |
# |   backbone.conv1         |   1.728K               |   86.704M |   3.211M       |
# |    backbone.conv1.weight |    (64, 3, 3, 3)       |           |                |
# |   backbone.bn1           |   0.128K               |   6.423M  |   0            |
# |    backbone.bn1.weight   |    (64,)               |           |                |
# |    backbone.bn1.bias     |    (64,)               |           |                |
# |   backbone.layer1        |   0.148M               |   7.424G  |   12.845M      |
# |    backbone.layer1.0     |    73.984K             |    3.712G |    6.423M      |
# |    backbone.layer1.1     |    73.984K             |    3.712G |    6.423M      |
# |   backbone.layer2        |   0.526M               |   6.593G  |   8.028M       |
# |    backbone.layer2.0     |    0.23M               |    2.887G |    4.817M      |
# |    backbone.layer2.1     |    0.295M              |    3.706G |    3.211M      |
# |   backbone.layer3        |   2.1M                 |   6.585G  |   4.014M       |
# |    backbone.layer3.0     |    0.919M              |    2.882G |    2.408M      |
# |    backbone.layer3.1     |    1.181M              |    3.703G |    1.606M      |
# |   backbone.layer4        |   8.394M               |   6.581G  |   2.007M       |
# |    backbone.layer4.0     |    3.673M              |    2.88G  |    1.204M      |
# |    backbone.layer4.1     |    4.721M              |    3.701G |    0.803M      |
# |  head.fc                 |  5.13K                 |           |                |
# |   head.fc.weight         |   (10, 512)            |           |                |
# |   head.fc.bias           |   (10,)                |           |                |
# |  neck.gap                |                        |  0.401M   |  0             |
# ==============================
# Input shape: (3, 224, 224)
# Flops: 27.276G
# Params: 11.174M
# Activation: 30.106M
# ==============================
# !!!Please be cautious if you use the results in papers. You may need to check if all ops are supported and verify that the flops computation is correct.
# The script finished successfully.

# %% [markdown]
# ### 5.2 分析模型预测正确和错误的典型例子
#
#
# ```bash
# mim run mmcls analyze_results ${CONFIG_FILE} ${RESULT} --out-dir ${OUT_DIR} --topk ${TOPK} --cfg-options ${CFG_OPTIONS}
# ```
# 参数讲解：
# + CONFIG_FILE：配置文件所在路径
# + RESULT：模型测试时保存的每个样本的预测结果文件（在 test 时，设置 `dump` 参数保存的文件），文件类型为 pkl 或者 json
# + OUT_DIR：保存模型预测正确和错误的典型例子图片的文件夹路径
# + TOPK：保存多少张模型预测正确和错误的典型例子。默认值为 20
# + CFG_OPTIONS：合入配置文件中的其他信息
#
# 详情请参考：[链接](https://mmclassification.readthedocs.io/en/latest/tools/analysis.html#view-typical-results)

# %% [markdown]
# **Step 1. 评估水果分类模型，并保存模型预测每个样本的结果文件**

# %%
# !python tools/test.py tutorial/fruit.py work_dirs/fruit/epoch_10.pth --dump tutorial/result_fruit.pkl
# Out:
# 03/20 05:30:07 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1279904812
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.13.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.13.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.14.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.7.0
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/20 05:30:07 - mmengine - INFO - Config:
# model = dict(
#     type='ImageClassifier',
#     backbone=dict(type='MobileNetV2', widen_factor=1.0),
#     neck=dict(type='GlobalAveragePooling'),
#     head=dict(
#         type='LinearClsHead',
#         num_classes=30,
#         in_channels=1280,
#         loss=dict(type='CrossEntropyLoss', loss_weight=1.0),
#         topk=(1, 5)))
# dataset_type = 'CustomDataset'
# data_preprocessor = dict(
#     num_classes=30,
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#     dict(type='CenterCrop', crop_size=224),
#     dict(type='PackClsInputs')
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='RandomResizedCrop', scale=224, backend='pillow'),
#             dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=True))
# val_dataloader = dict(
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# val_evaluator = dict(type='Accuracy', topk=(1, 5))
# test_dataloader = dict(
#     pin_memory=True,
#     collate_fn=dict(type='default_collate'),
#     batch_size=32,
#     num_workers=5,
#     dataset=dict(
#         type='CustomDataset',
#         data_root='data/fruit30_split_en',
#         data_prefix='val',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='ResizeEdge', scale=256, edge='short', backend='pillow'),
#             dict(type='CenterCrop', crop_size=224),
#             dict(type='PackClsInputs')
#         ]),
#     sampler=dict(type='DefaultSampler', shuffle=False))
# test_evaluator = [
#     dict(type='Accuracy', topk=(1, 5)),
#     dict(type='DumpResults', out_file_path='tutorial/result_fruit.pkl')
# ]
# optim_wrapper = dict(
#     optimizer=dict(type='SGD', lr=0.005, momentum=0.9, weight_decay=4e-05))
# param_scheduler = dict(type='StepLR', by_epoch=True, step_size=1, gamma=0.98)
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# auto_scale_lr = dict(base_batch_size=256)
# default_scope = 'mmcls'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=60),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=1),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='VisualizationHook', enable=False))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='ClsVisualizer', vis_backends=[dict(type='LocalVisBackend')])
# log_level = 'INFO'
# load_from = 'work_dirs/mobilenet-v2_1xb32_fruit30/epoch_10.pth'
# resume = False
# randomness = dict(seed=None, deterministic=False)
# launcher = 'none'
# work_dir = './work_dirs/mobilenet-v2_1xb32_fruit30'
#
# 03/20 05:30:07 - mmengine - WARNING - The "visualizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:07 - mmengine - WARNING - The "vis_backend" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:08 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:10 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/20 05:30:10 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:10 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/20 05:30:10 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:10 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:10 - mmengine - WARNING - The "data sampler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 03/20 05:30:10 - mmengine - WARNING - The "metric" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:30:10 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: work_dirs/mobilenet-v2_1xb32_fruit30/epoch_10.pth
# 03/20 05:30:10 - mmengine - INFO - Load checkpoint from work_dirs/mobilenet-v2_1xb32_fruit30/epoch_10.pth
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 03/20 05:30:20 - mmengine - INFO - Results has been saved to tutorial/result_fruit.pkl.
# 03/20 05:30:20 - mmengine - INFO - Epoch(test) [34/34]  accuracy/top1: 91.9295  accuracy/top5: 98.9796data_time: 0.1802  time: 0.2400

# %% [markdown]
# **Step 2. 保存模型预测正确和错误的典型例子**

# %%
# !mkdir tutorial/typical_result
# !mim run mmcls analyze_results tutorial/fruit.py tutorial/result_fruit.pkl  --out-dir tutorial/typical_result
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/analysis_tools/analyze_results.py for command analyze_results.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/analysis_tools/analyze_results.py tutorial/mobilenet-v2_1xb32_fruit30.py tutorial/result_fruit.pkl --out-dir tutorial/typical_result.
# 03/20 05:30:49 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# The script finished successfully.

# %% [markdown]
# **Step 3. 分析错误的典型例子**
#
# 真实标签：猕猴桃
#
# 预测标签：梨
#
# <img src="img/fail_example_2.png">

# %% [markdown]
# ### 5.3 绘制混淆矩阵（2.0暂时还不支持，可关注文档更新）
#
# MMCls 0.x 里该功能是在 mmcls.core.evaluation 里：https://mmclassification.readthedocs.io/en/latest/api/generated/mmcls.core.calculate_confusion_matrix.html#mmcls.core.calculate_confusion_matrix
# 但根据 1.0 里的迁移说明：https://mmclassification.readthedocs.io/en/1.x/migration.html#mmcls-core
# 该 mmcls.core.evaluation 是迁移至 mmcls.evaluation 里了
# 查阅文档，暂时还不支持

# %% [markdown]
# ### 5.4 可视化数据增强流程
#
# ```bash
# mim run mmcls browse_dataset ${CONFIG_FILE} \
#                     [--output-dir ${OUTPUT_DIR}] \
#                     [--phase ${DATASET_PHASE}] \
#                     [--show-number ${NUMBER_IMAGES_DISPLAY}] \
#                     [--show-interval ${SHOW_INTERRVAL}] \
#                     [--mode ${DISPLAY_MODE}] \
#                     [--rescale-factor ${RESCALE_FACTOR}] \
#                     [--channel-order ${CHANNEL_ORDER}] \
#                     [--cfg-options ${CFG_OPTIONS}]
# ```
# 参数讲解：
# + CONFIG_FILE：配置文件所在路径
# + OUTPUT_DIR：保存可视化图片的路径。如果不设置，则默认为 `''`，表示不保存
# + DATASET_PHASE：选择可视化数据集的训练集、验证集还是测试集。取值必须是 `['train', 'val', 'test']` 中的一个。如果不设置，默认是 `train`
# + NUMBER_IMAGES_DISPLAY：可视化图片的数量。如果不设置，默认显示数据集里所有的图片
# + SHOW_INTERRVAL：设置显示图片的间隔
# + DISPLAY_MODE：展示图片的模式。取值可以是 `['original', 'transformed', 'concat', 'pipeline']` 中的一个。如果不设置，默认是 `transformed`
# + RESCALE_FACTOR：图片尺寸缩放因子。如果图片本身过于太小或者小大，可以设置该参数，将图片可视化至合适的尺寸范围。
# + CHANNEL_ORDER：展示图片的通道顺序。取值可以是 `BGR` 或者是 `RGB`。如果没有指定，默认是 `BGR`
# + CFG_OPTIONS：合入配置文件中的其他信息
#
# 详情请参考：[链接](https://mmclassification.readthedocs.io/en/1.x/useful_tools/dataset_visualization.html#dataset-visualization)

# %% [markdown]
# **1. 可视化 CIFAR-10 数据集里的原图**
#
# 该数据集的图片尺寸很小，可以将 `rescale-factor` 参数设置大一些
#
# `mode：'original'`

# %%
# CIFAR
# !mkdir tutorial/cifar10_original_visualization
# !mim run mmcls browse_dataset tutorial/resnet18_8xb16_cifar10.py --output-dir 'tutorial/cifar10_original_visualization' --show-number 5 --mode 'original' --rescale-factor 10 --channel-order 'RGB'
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py for command browse_dataset.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py tutorial/resnet18_8xb16_cifar10.py --output-dir tutorial/cifar10_original_visualization --show-number 5 --mode original --rescale-factor 10 --channel-order RGB.
# 03/20 05:31:58 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:31:58 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:32:02 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [>>] 5/5, 7.7 task/s, elapsed: 1s, ETA:     0sThe script finished successfully.

# %%
# 水果
# !mkdir -p tutorial/fruit_aug
# !mim run mmcls browse_dataset tutorial/fruit.py --output-dir 'tutorial/fruit_aug' --show-number 5 --mode 'original'

# %% [markdown]
# **2. 并列可视化 CIFAR-10 数据集里的原图和按配置文件里数据加载流水线变换过后的图**
#
# `mode：'concat'`
#
# `resnet18_8xb16_cifar10.py` 配置文件里训练集的数据加载流水线处理如下：
# ```bash
# pipeline=[
#     dict(type='RandomCrop', crop_size=32, padding=4),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]),
# ```
# <img src='img/browseDataset_concat.png'></img>

# %%
# CIFAR
# !mkdir tutorial/cifar10_concat_visualization
# !mim run mmcls browse_dataset tutorial/resnet18_8xb16_cifar10.py --output-dir 'tutorial/cifar10_concat_visualization' --show-number 5 --mode 'concat' --rescale-factor 10 --channel-order 'RGB'
# Out:
# mkdir: cannot create directory ‘tutorial/cifar10_concat_visualization’: File exists
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py for command browse_dataset.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py tutorial/resnet18_8xb16_cifar10.py --output-dir tutorial/cifar10_concat_visualization --show-number 5 --mode concat --rescale-factor 10 --channel-order RGB.
# 03/20 05:32:42 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:32:42 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:32:45 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [>>] 5/5, 4.5 task/s, elapsed: 1s, ETA:     0sThe script finished successfully.

# %%
# 水果
# !mkdir -p tutorial/fruit_aug
# !mim run mmcls browse_dataset tutorial/fruit.py --output-dir 'tutorial/fruit_aug' --show-number 5 --mode 'concat'

# %% [markdown]
# **3. 按配置文件里数据加载流水线处理过程图**
#
# `mode：'pipeline'`
#
# `resnet18_8xb16_cifar10.py` 配置文件里训练集的数据加载流水线处理如下：
# ```bash
# pipeline=[
#     dict(type='RandomCrop', crop_size=32, padding=4),
#     dict(type='RandomFlip', prob=0.5, direction='horizontal'),
#     dict(type='PackClsInputs')
# ]),
# ```
# <img src='img/browseDataset_pipeline.png'></img>

# %%
# CIFAR
# !mkdir tutorial/cifar10_pipeline_visualization
# !mim run mmcls browse_dataset tutorial/resnet18_8xb16_cifar10.py --output-dir 'tutorial/cifar10_pipeline_visualization' --show-number 5 --mode 'pipeline' --rescale-factor 10 --channel-order 'RGB'
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py for command browse_dataset.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/browse_dataset.py tutorial/resnet18_8xb16_cifar10.py --output-dir tutorial/cifar10_pipeline_visualization --show-number 5 --mode pipeline --rescale-factor 10 --channel-order RGB.
# 03/20 05:33:04 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:04 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:08 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.
# [>>] 5/5, 4.2 task/s, elapsed: 1s, ETA:     0sThe script finished successfully.

# %%
# 水果
# !mkdir -p tutorial/fruit_aug
# !mim run mmcls browse_dataset tutorial/fruit.py --output-dir 'tutorial/fruit_aug' --show-number 5 --mode 'pipeline'

# %% [markdown]
# ### 5.5 可视化训练过程中的超参数变化图
#
# 在不进行训练的情况下，用可视化工具检查超参数（比如 `学习率 learning rate` 和 `动量 momentum`）是否按照自己的设想进行变化。
#
# ```bash
# mim run mmcls vis_scheduler ${CONFIG_FILE} \
#                     [-p, --parameter ${PARAMETER_NAME}] \
#                     [-d, --dataset-size ${DATASET_SIZE}] \
#                     [-n, --ngpus ${NUM_GPUs}] \
#                     [-s, --save-path ${SAVE_PATH}] \
#                     [--title ${TITLE}] \
#                     [--style ${STYLE}] \
#                     [--window-size ${WINDOW_SIZE}] \
#                     [--cfg-options]
# ```
# 参数讲解：
# + CONFIG_FILE：配置文件所在路径
# + PARAMETER_NAME：检查的超参数名称。取值可以是 `['lr', 'momentum']` 中的一个。如果不设置，默认是 `lr`
# + DATASET_SIZE：数据集大小。**注意：默认是不用设置的，程序会自动按照配置文件里的设置构建数据集以获得数据集的大小，但是加载数据集是一个相对比较耗时的步骤。所以可以通过直接设置数据集大小来跳过构建数据集的过程，节省时间**
# + NUM_GPUs：用于训练的 GPU 数量，默认为 1
# + SAVE_PATH：可视化超参数变化图的保存路径
# + TITLE：可视化超参数变化图的标题，默认值是配置文件的名字
# + STYLE：plt 的风格，默认值是 `whitegrid`
# + WINDOW_SIZE：设置用于可视化窗格的大小，设置格式为 `'W*H'`。默认为 `'12*7'`
# + CFG_OPTIONS：合入配置文件中的其他信息
#
# 详情请参考：[链接](https://mmclassification.readthedocs.io/en/1.x/useful_tools/scheduler_visualization.html#)

# %% [markdown]
# **1. 可视化 `resnet18_8xb16_cifar10.py` 配置文件的学习率变化图**
#
# <img src='img/lr_visualization.png'></img>

# %%
# !mim download mmcls --config resnet18_8xb16_cifar10 --dest tutorial/
# !mim run mmcls vis_scheduler tutorial/resnet18_8xb16_cifar10.py --parameter 'lr' --ngpus 1 --save-path 'tutorial/resnet18_8xb16_cifar10_lr.png'
# Out:
# processing resnet18_8xb16_cifar10...
# resnet18_b16x8_cifar10_20210528-bd6371c8.pth exists in /content/mmclassification/tutorial
# Successfully dumped resnet18_8xb16_cifar10.py to /content/mmclassification/tutorial
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/vis_scheduler.py for command vis_scheduler.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/vis_scheduler.py tutorial/resnet18_8xb16_cifar10.py --parameter lr --ngpus 1 --save-path tutorial/resnet18_8xb16_cifar10_lr.png.
# Param_scheduler :
# {
#   "type": "MultiStepLR",
#   "by_epoch": true,
#   "milestones": [
#     100,
#     150
#   ],
#   "gamma": 0.1
# }
# 03/20 05:33:48 - mmengine - WARNING - The "dataset" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:48 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
#
# Dataset infos:
#  - Dataset size: 50000
#  - Batch size per GPU: 16
#  - Number of GPUs: 1
#  - Total batch size: 16
#  - Iterations per epoch: 3125
#
# 03/20 05:33:51 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:53 - mmengine - WARNING - The "hook" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:53 - mmengine - WARNING - The "optimizer wrapper constructor" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:53 - mmengine - WARNING - The "optimizer" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:53 - mmengine - WARNING - The "optimizer_wrapper" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# 03/20 05:33:53 - mmengine - WARNING - The "parameter scheduler" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# /usr/local/lib/python3.9/dist-packages/mmengine/optim/scheduler/param_scheduler.
# py:198: UserWarning: Detected call of `scheduler.step()`
# before`optimizer.step()`. In PyTorch 1.1.0 and later, youshould call them in the
# opposite order: `optimizer.step()` before `scheduler.step()`. Failure to do this
# will result in PyTorch skipping the first value of the parameter value schedule.
# See more details at
# https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200/200 epochs
#
# The Learning Rate graph is saved at tutorial/resnet18_8xb16_cifar10_lr.png
# Figure(1200x700)
# The script finished successfully.

# %% [markdown]
# ### 5.6 可视化类别激活图
#
# 目前，我们支持类别激活可视化的方法有：`GradCAM`、`GradCAM++`、`XGradCAM`、`EigenCAM`、`EigenGradCAM` 和 `LayerCAM`
#
#
# ```bash
# mim run mmcls vis_cam ${IMG} ${CONFIG_FILE} ${CHECKPOINT} \
#                 [--target-layers ${TARGET-LAYERS}] \
#                 [--preview-model] \
#                 [--method ${METHOD}] \
#                 [--target-category ${TARGET-CATEGORY}] \
#                 [--save-path ${SAVE_PATH}] \
#                 [--vit-like] \
#                 [--num-extra-tokens ${NUM-EXTRA-TOKENS}]
#                 [--aug_smooth] \
#                 [--eigen_smooth] \
#                 [--device ${DEVICE}] \
#                 [--cfg-options ${CFG-OPTIONS}]
# ```
# 参数讲解：
# + IMG：要进行类别激活可视化的图片路径
# + CONFIG_FILE：配置文件所在路径
# + CHECKPOINT：模型文件所在路径
# + TARGET-LAYERS：获取哪一层或多层的激活图。如果不设置，默认为最后一个 block 的 norm layer。以 `ResNet-50` 为例：
#     + 'backbone.layer4'：第四个残差层的输出
#     + 'backbone.layer4.2'：第四个残差层里第三个 BottleNeck block 的输出
#     + 'backbone.layer4.2.conv1'：上述 BottleNeck block 里 conv1 的输出
# + preview-model：是否打印模型里所有层的名字
# + METHOD：使用哪一个类别激活可视化的方法。默认使用 `GradCAM`
# + TARGET-CATEGORY：设置目标类别。如果不设置，默认使用网络预测的类别
# + SAVE_PATH：类别激活可视化图的保存路径
# + DEVICE：使用设备类型。默认为 `cpu`
# + CFG_OPTIONS：合入配置文件中的其他信息
#
# 更多参数请参考：[链接](https://mmclassification.readthedocs.io/en/1.x/useful_tools/cam_visualization.html)

# %% [markdown]
# **Step 1. 安装 `pytorch-grad-cam`**

# %%
# !pip install "grad-cam>=1.3.6"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting grad-cam>=1.3.6
#   Downloading grad-cam-1.4.6.tar.gz (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (0.14.1+cu116)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (3.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (8.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (4.65.0)
# Collecting ttach
#   Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (1.22.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from grad-cam>=1.3.6) (4.6.0.66)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.1->grad-cam>=1.3.6) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8.2->grad-cam>=1.3.6) (2.27.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->grad-cam>=1.3.6) (23.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->grad-cam>=1.3.6) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->grad-cam>=1.3.6) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->grad-cam>=1.3.6) (1.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->grad-cam>=1.3.6) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam>=1.3.6) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8.2->grad-cam>=1.3.6) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8.2->grad-cam>=1.3.6) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8.2->grad-cam>=1.3.6) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8.2->grad-cam>=1.3.6) (2.0.12)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.4.6-py3-none-any.whl size=38262 sha256=1bee277337b042deec9e9cbd974c9c16e76e81505d77449195795272f4e3c03c
#   Stored in directory: /root/.cache/pip/wheels/9b/ae/bd/221d138b169c4867b2ae5c893474d0b23bae6e4750bc95bc55
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.4.6 ttach-0.0.3

# %% [markdown]
# **Step 2. 下载 ResNet-50 模型以及配置文件**

# %%
# !mim download mmcls --config resnet50_8xb32_in1k --dest tutorial/
# Out:
# processing resnet50_8xb32_in1k...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.8/97.8 MiB 11.3 MB/s eta 0:00:00
# Successfully downloaded resnet50_8xb32_in1k_20210831-ea4938fc.pth to /content/mmclassification/tutorial
# Successfully dumped resnet50_8xb32_in1k.py to /content/mmclassification/tutorial

# %% [markdown]
# **Step 3. 可视化示例图片 `demo/cat-dog.png` 的 `狗` 类别激活图**
#
# 在 ImageNet 里，238 对应的类别是：'Greater Swiss Mountain dog'

# %%
# !mim run mmcls vis_cam demo/cat-dog.png tutorial/resnet50_8xb32_in1k.py tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth --target-layers 'backbone.layer4.2' --target-category 238 --save-path 'tutorial/dog_activation_map.png'
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/vis_cam.py for command vis_cam.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/vis_cam.py demo/cat-dog.png tutorial/resnet50_8xb32_in1k.py tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth --target-layers backbone.layer4.2 --target-category 238 --save-path tutorial/dog_activation_map.png.
# 03/20 05:35:13 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Loads checkpoint by local backend from path: tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 03/20 05:35:13 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# The script finished successfully.

# %% [markdown]
# **Step 4. 可视化示例图片 `demo/cat-dog.png` 的 `猫` 类别激活图**
#
# 在 ImageNet 里，281 对应的类别是：'tabby, tabby cat'

# %%
# !mim run mmcls vis_cam demo/cat-dog.png tutorial/resnet50_8xb32_in1k.py tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth --target-layers 'backbone.layer4.2' --target-category 281 --save-path 'tutorial/cat_activation_map.png'
# Out:
# Use the script /content/mmclassification/mmcls/.mim/tools/visualizations/vis_cam.py for command vis_cam.
# The command to call is /usr/bin/python3 /content/mmclassification/mmcls/.mim/tools/visualizations/vis_cam.py demo/cat-dog.png tutorial/resnet50_8xb32_in1k.py tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth --target-layers backbone.layer4.2 --target-category 281 --save-path tutorial/cat_activation_map.png.
# 03/20 05:35:29 - mmengine - WARNING - The "model" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# Loads checkpoint by local backend from path: tutorial/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 03/20 05:35:30 - mmengine - WARNING - The "transform" registry in mmcls did not set import location. Fallback to call `mmcls.utils.register_all_modules` instead.
# The script finished successfully.

# %% [markdown]
# ---

# %% [markdown]
# ## 6. 代码解析
#
# MMClassification 和 MMEngine 之间的关系
#
# <img src='img/MMCls 和 MMEngine 的关系 1.png'></img>
# <img src='img/MMCls 和 MMEngine 的关系 2.png'></img>
#
# MMEngine 详见：https://mmengine.readthedocs.io/zh_CN/latest/get_started/introduction.html
